# %% [markdown]
# # Imports
# ___

# %%
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (3.3.1)
# Requirement already satisfied: gensim in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: numpy>=1.20.0 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.20.1)
# Requirement already satisfied: funcy in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: scipy in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.6.2)
# Requirement already satisfied: sklearn in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: pandas>=1.2.0 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.2.4)
# Requirement already satisfied: joblib in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: numexpr in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: setuptools in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (52.0.0.post20210125)
# Requirement already satisfied: jinja2 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: future in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: scikit-learn in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2.0->pyLDAvis) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from jinja2->pyLDAvis) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->pyLDAvis) (2.1.0)

# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, TwoSlopeNorm
import seaborn as sns

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.cluster import DBSCAN, KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer

# Import CountVectorizer from feature_extraction.text.
from sklearn.feature_extraction.text import CountVectorizer

from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

from __future__ import print_function 
import pyLDAvis
import pyLDAvis.sklearn

import string
import collections

from pprint import pprint
# Out:
# /Users/jackrayner/opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload

# %% [markdown]
# Warnings Code:
# https://machinelearningmastery.com/how-to-fix-futurewarning-messages-in-scikit-learn/

# %% [markdown]
# # Bring in Cleaned Dataset
# ___

# %%
articles = pd.read_csv('Datasets/articles_clean.csv')

# %%
articles.head()
# Out:
#                                             abstract  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                              snippet  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                       lead_paragraph  \
# 0   The United States, supported by Britain, toda...
# 1  IT will be, Americans have already been warned...
# 2  THE photographer Edward Grazda first visited A...
# 3  In the late 1980's, an American-based agent fo...
# 4   TOPDARA, Afghanistan, Oct. 7 — Sending bright...
#
#                                             headline  \
# 0  "U.S. and Britain Clearing Way for "Relentless...
# 1                                         "The World
# 2  "Art/Architecture; Images of Afghanistan, Befo...
# 3        "In 80"s, Afghan Militias Used U.S. Rifles"
# 4                 "Thunderous Attack Heard in Kabul"
#
#                                             keywords  \
# 0  The United States Taliban Rhode Television  Te...
# 1  World Trade Center (NYC) Airlines and Airplane...
# 2        Afghanistan Grazda Woodward   Photography
# 3  New York City Russia Washington (DC) Afghanist...
# 4  Afghanistan Taliban Dostum United States Polit...
#
#                     pub_date              news_desk    section_name  \
# 0  2001-10-07 05:00:00+00:00          International           World
# 1  2001-10-07 05:00:00+00:00    Week in Review Desk  Week in Review
# 2  2001-10-07 05:00:00+00:00  Arts and Leisure Desk            Arts
# 3  2001-10-07 05:00:00+00:00          National Desk            U.S.
# 4  2001-10-07 05:00:00+00:00          International           World
#
#   type_of_material  word_count  \
# 0             News        1333
# 1             News        1322
# 2        Interview        1638
# 3             News         603
# 4             News         611
#
#                                                  uri  \
# 0  nyt://article/02612e18-76c0-5447-bace-71473568...
# 1  nyt://article/0abd157f-d390-5787-bf89-4e87dad4...
# 2  nyt://article/15581e37-54ea-5aa4-bc80-34588ab1...
# 3  nyt://article/17f9cbdb-ff36-5df1-8a37-5c02edbb...
# 4  nyt://article/1a2a8209-9dd4-501b-a988-0c2adfc9...
#
#                                             all_text  overall_sentiment
# 0  The United States, supported by Britain, today...            -0.9648
# 1  Government can be expected to try to control, ...            -0.9761
# 2  Richard B Woodward interviews photographer Edw...            -0.6815
# 3  Violence Policy Center, Washington-based group...            -0.9661
# 4  Sending bright flashes of light and loud concu...             0.9022

# %%
articles.shape
# Out:
# (37398, 13)

# %% [markdown]
# # Topic Clustering with LDA
# ___

# %% [markdown]
# ### Add overemphasized words to stopwords

# %%
new_stop_words = stopwords.words('english')
new_stop_words.append('administration')
new_stop_words.append('says')
new_stop_words.append('said')
new_stop_words.append('photo')
new_stop_words.append('one')
new_stop_words.append('two')

# %% [markdown]
# ### Create Class for Easy LDA Modeling

# %%
class lda_model:
    def __init__(self, corpus, topic_count):
        self
        self.text = corpus
        self.topic_count = topic_count

    def fit(self):
    #     initialize and define params for vectorizer
        self.vectorizer = TfidfVectorizer(tokenizer=None,
                                     stop_words=new_stop_words,
                                     max_df=0.5,
                                     min_df=0.1,
                                     lowercase=True)

    #     vectorize text
        self.tfidf_model = self.vectorizer.fit_transform(self.text)

    #     perform lda
        self.lda = LatentDirichletAllocation(n_components=self.topic_count,
            random_state=0)
        self.lda_matrix = self.lda.fit_transform(self.tfidf_model)
        self.lda_components = self.lda.components_
        self.terms = self.vectorizer.get_feature_names_out()        
    
    def topics(self):
        #     get topics
        terms = self.vectorizer.get_feature_names()
        
        lda_topics = ''
        for index, component in enumerate(self.lda_components):
            zipped = zip(terms, component)
            top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:7]
            top_terms_list=list(dict(top_terms_key).keys())
            lda_topics = lda_topics+f"Topic {str(index)}: {top_terms_list}" + '\n'
        return print(lda_topics) 
    
    def viz(self):
        return self.lda, self.tfidf_model, self.vectorizer  
    
    def components (self):
        return self.lda_components
    
    def columns(self):
        # To view what topics are assigned to the douments:
        doc_topic = self.lda.transform(self.tfidf_model)

        return [doc_topic[n].argmax() for n in range (doc_topic. shape[0])]

# %% [markdown]
# Helped with returning topics: https://machinelearninggeek.com/latent-dirichlet-allocation-using-scikit-learn/

# %% [markdown]
# ### Use for loop to determine the ideal number of topics

# %%
for num in range(2, 13):
    print(f'Topics Count: {num}')
    model = lda_model(articles['all_text'], num)
    model.fit()
    print(model.topics(), '\n')
# Out:
# Topics Count: 2
# Topic 0: ['afghanistan', 'president', 'military', 'united', 'washington', 'taliban', 'states']
# Topic 1: ['new', 'war', 'american', 'afghan', 'officials', 'government', 'iraq']
#
# None
#
# Topics Count: 3
# Topic 0: ['president', 'military', 'washington', 'taliban', 'afghanistan', 'american', 'afghan']
# Topic 1: ['new', 'afghan', 'american', 'officials', 'government', 'afghanistan', 'taliban']
# Topic 2: ['afghanistan', 'war', 'iraq', 'united', 'states', 'american', 'military']
#
# None
#
# Topics Count: 4
# Topic 0: ['president', 'military', 'washington', 'american', 'officials', 'afghanistan', 'taliban']
# Topic 1: ['new', 'afghan', 'officials', 'american', 'government', 'taliban', 'afghanistan']
# Topic 2: ['afghanistan', 'war', 'taliban', 'afghan', 'american', 'military', 'government']
# Topic 3: ['iraq', 'united', 'states', 'american', 'war', 'washington', 'military']
#
# None
#
# Topics Count: 5
# Topic 0: ['american', 'afghan', 'taliban', 'afghanistan', 'military', 'officials', 'washington']
# Topic 1: ['officials', 'government', 'afghan', 'american', 'afghanistan', 'washington', 'new']
# Topic 2: ['war', 'afghanistan', 'afghan', 'american', 'military', 'iraq', 'united']
# Topic 3: ['new', 'united', 'states', 'washington', 'american', 'president', 'military']
# Topic 4: ['president', 'iraq', 'military', 'washington', 'american', 'war', 'afghanistan']
#
# None
#
# Topics Count: 6
# Topic 0: ['american', 'taliban', 'afghanistan', 'afghan', 'military', 'officials', 'president']
# Topic 1: ['government', 'officials', 'afghan', 'afghanistan', 'american', 'new', 'washington']
# Topic 2: ['war', 'iraq', 'american', 'afghanistan', 'afghan', 'military', 'united']
# Topic 3: ['new', 'united', 'states', 'american', 'washington', 'president', 'military']
# Topic 4: ['president', 'military', 'iraq', 'washington', 'american', 'officials', 'afghanistan']
# Topic 5: ['afghanistan', 'washington', 'afghan', 'military', 'president', 'american', 'united']
#
# None
#
# Topics Count: 7
# Topic 0: ['taliban', 'american', 'afghanistan', 'afghan', 'officials', 'military', 'government']
# Topic 1: ['government', 'afghan', 'afghanistan', 'officials', 'american', 'new', 'taliban']
# Topic 2: ['war', 'iraq', 'american', 'afghanistan', 'afghan', 'military', 'united']
# Topic 3: ['new', 'united', 'states', 'american', 'washington', 'president', 'afghanistan']
# Topic 4: ['president', 'iraq', 'washington', 'american', 'new', 'war', 'afghanistan']
# Topic 5: ['afghanistan', 'washington', 'afghan', 'president', 'american', 'united', 'states']
# Topic 6: ['military', 'officials', 'american', 'washington', 'afghanistan', 'united', 'states']
#
# None
#
# Topics Count: 8
# Topic 0: ['american', 'afghan', 'afghanistan', 'military', 'officials', 'washington', 'war']
# Topic 1: ['government', 'afghan', 'afghanistan', 'officials', 'new', 'american', 'president']
# Topic 2: ['taliban', 'afghanistan', 'afghan', 'officials', 'american', 'government', 'war']
# Topic 3: ['new', 'united', 'states', 'washington', 'american', 'president', 'afghanistan']
# Topic 4: ['president', 'iraq', 'washington', 'american', 'new', 'afghanistan', 'war']
# Topic 5: ['afghanistan', 'washington', 'afghan', 'president', 'united', 'new', 'american']
# Topic 6: ['military', 'officials', 'washington', 'american', 'afghanistan', 'iraq', 'new']
# Topic 7: ['war', 'iraq', 'afghanistan', 'american', 'washington', 'new', 'military']
#
# None
#
# Topics Count: 9
# Topic 0: ['american', 'afghan', 'afghanistan', 'officials', 'washington', 'military', 'war']
# Topic 1: ['government', 'officials', 'afghan', 'afghanistan', 'washington', 'new', 'american']
# Topic 2: ['taliban', 'afghanistan', 'afghan', 'american', 'officials', 'government', 'war']
# Topic 3: ['new', 'united', 'states', 'washington', 'american', 'president', 'officials']
# Topic 4: ['iraq', 'war', 'afghanistan', 'american', 'president', 'new', 'military']
# Topic 5: ['afghanistan', 'afghan', 'united', 'washington', 'american', 'new', 'president']
# Topic 6: ['military', 'washington', 'officials', 'american', 'afghanistan', 'new', 'united']
# Topic 7: ['war', 'washington', 'american', 'afghanistan', 'new', 'iraq', 'afghan']
# Topic 8: ['president', 'washington', 'new', 'american', 'afghanistan', 'war', 'government']
#
# None
#
# Topics Count: 10
# Topic 0: ['american', 'afghan', 'afghanistan', 'military', 'war', 'officials', 'washington']
# Topic 1: ['government', 'afghan', 'afghanistan', 'officials', 'american', 'taliban', 'new']
# Topic 2: ['taliban', 'afghanistan', 'afghan', 'officials', 'american', 'government', 'war']
# Topic 3: ['new', 'washington', 'president', 'afghanistan', 'american', 'war', 'government']
# Topic 4: ['iraq', 'war', 'afghanistan', 'american', 'military', 'president', 'washington']
# Topic 5: ['afghanistan', 'afghan', 'washington', 'war', 'president', 'officials', 'american']
# Topic 6: ['military', 'officials', 'washington', 'american', 'afghanistan', 'war', 'president']
# Topic 7: ['war', 'washington', 'american', 'afghanistan', 'iraq', 'afghan', 'military']
# Topic 8: ['president', 'washington', 'american', 'afghanistan', 'war', 'new', 'government']
# Topic 9: ['united', 'states', 'american', 'washington', 'military', 'afghanistan', 'officials']
#
# None
#
# Topics Count: 11
# Topic 0: ['american', 'afghan', 'afghanistan', 'washington', 'war', 'military', 'officials']
# Topic 1: ['government', 'officials', 'new', 'afghanistan', 'washington', 'president', 'afghan']
# Topic 2: ['taliban', 'afghanistan', 'afghan', 'officials', 'american', 'government', 'war']
# Topic 3: ['new', 'washington', 'president', 'afghanistan', 'war', 'iraq', 'united']
# Topic 4: ['iraq', 'war', 'afghanistan', 'american', 'military', 'president', 'washington']
# Topic 5: ['afghanistan', 'washington', 'president', 'war', 'american', 'afghan', 'officials']
# Topic 6: ['military', 'officials', 'washington', 'american', 'afghanistan', 'war', 'new']
# Topic 7: ['war', 'washington', 'american', 'afghanistan', 'iraq', 'afghan', 'military']
# Topic 8: ['president', 'washington', 'american', 'afghanistan', 'new', 'war', 'officials']
# Topic 9: ['united', 'states', 'american', 'military', 'washington', 'afghanistan', 'officials']
# Topic 10: ['afghan', 'afghanistan', 'officials', 'american', 'military', 'taliban', 'war']
#
# None
#
# Topics Count: 12
# Topic 0: ['american', 'washington', 'afghanistan', 'officials', 'military', 'afghan', 'war']
# Topic 1: ['government', 'new', 'officials', 'afghanistan', 'washington', 'president', 'afghan']
# Topic 2: ['taliban', 'afghanistan', 'afghan', 'officials', 'american', 'government', 'war']
# Topic 3: ['new', 'washington', 'president', 'afghanistan', 'war', 'iraq', 'american']
# Topic 4: ['iraq', 'war', 'afghanistan', 'american', 'military', 'president', 'washington']
# Topic 5: ['afghanistan', 'afghan', 'washington', 'president', 'war', 'american', 'military']
# Topic 6: ['military', 'washington', 'american', 'officials', 'afghanistan', 'war', 'president']
# Topic 7: ['war', 'washington', 'afghanistan', 'american', 'iraq', 'new', 'military']
# Topic 8: ['president', 'washington', 'american', 'new', 'afghanistan', 'war', 'officials']
# Topic 9: ['united', 'states', 'american', 'washington', 'afghanistan', 'military', 'president']
# Topic 10: ['officials', 'afghanistan', 'afghan', 'american', 'military', 'washington', 'taliban']
# Topic 11: ['afghan', 'american', 'afghanistan', 'war', 'military', 'taliban', 'officials']
#
# None

# %% [markdown]
# #### With 5 topics
# 1. Seems to be US Military Control in Afghanistan
# 2. Seems to relate more to Government Centric Updates
# 3. Seems to address General Public Opinion
# 4. White House Press Releases
# 5. Military Press Releases

# %% [markdown]
# #### Questions to ask:
# 1. Who(groups or individuals) would a sentiment of each topic represent
# 2. How does the sentiment of these groups change
# 3. what does it mean if they stay the same and how is the project still useful

# %%
articles[articles['all_text'].str.contains('one')]['all_text'][2]
# Out:
# 'Richard B Woodward interviews photographer Edward Grazda, who comments on his work photographing recent history of Afghanistan; photo (M) - Richard B Woodward interviews photographer Edward Grazda, who comments on his work photographing recent history of Afghanistan; photo (M) - THE photographer Edward Grazda first visited Afghanistan in 1980, a year after the Russian entry into its civil war. During more than 15 subsequent trips over the next 20 years, he has amassed one of the most comprehensive, if personal, archives on the recent historical travails of the Afghan people. - "Art/Architecture; Images of Afghanistan, Before They Were Banned"'

# %%
articles[articles['all_text'].str.contains('new')]['all_text'][37382]
# Out:
# 'As American troops rush to complete their withdrawal by President Biden’s Tuesday deadline, many Afghans are afraid that reprisals from the country’s new rulers will soon follow. -  - As American troops rush to complete their withdrawal by President Biden’s Tuesday deadline, many Afghans are afraid that reprisals from the country’s new rulers will soon follow. - "Some Afghans say that enemies of the Taliban have begun to disappear."'

# %% [markdown]
# ### Visualize Topic Clusters

# %%
pyLDAvis.enable_notebook()

# %% [markdown]
# Adapting code to SKlearn help from: https://github.com/bmabey/pyLDAvis/blob/master/notebooks/sklearn.ipynb

# %%
model = lda_model(articles['all_text'], 5)
model.fit()
lda_tf, dtm_tf, tf_vectorizer = model.viz()

# %%
model.topics()
# Out:
# Topic 0: ['american', 'afghan', 'taliban', 'afghanistan', 'military', 'officials', 'washington']
# Topic 1: ['officials', 'government', 'afghan', 'american', 'afghanistan', 'washington', 'new']
# Topic 2: ['war', 'afghanistan', 'afghan', 'american', 'military', 'iraq', 'united']
# Topic 3: ['new', 'united', 'states', 'washington', 'american', 'president', 'military']
# Topic 4: ['president', 'iraq', 'military', 'washington', 'american', 'war', 'afghanistan']

# %%
# %matplotlib inline

model_viz = pyLDAvis.sklearn.prepare(lda_model =lda_tf, dtm=dtm_tf, vectorizer=tf_vectorizer)
model_viz
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.138391  0.323056       1        1  24.542994
# 0      0.195954  0.054201       2        1  23.367739
# 3     -0.387988 -0.222980       3        1  20.523679
# 2      0.257420 -0.223210       4        1  17.135886
# 1      0.073005  0.068932       5        1  14.429702, topic_info=           Term         Freq        Total Category  logprob  loglift
# 12          war  3828.000000  3828.000000  Default  14.0000  14.0000
# 6           new  4114.000000  4114.000000  Default  13.0000  13.0000
# 1   afghanistan  5899.000000  5899.000000  Default  12.0000  12.0000
# 3    government  2834.000000  2834.000000  Default  11.0000  11.0000
# 7     officials  3002.000000  3002.000000  Default  10.0000  10.0000
# ..          ...          ...          ...      ...      ...      ...
# 9        states     0.266114  2189.145005   Topic5 -10.0895  -7.0792
# 10      taliban     0.269150  2235.141281   Topic5 -10.0781  -7.0887
# 11       united     0.266515  2537.506341   Topic5 -10.0880  -7.2254
# 4          iraq     0.266013  2564.821599   Topic5 -10.0898  -7.2380
# 12          war     0.267318  3828.670619   Topic5 -10.0850  -7.6337
#
# [84 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 0         2  0.903366       afghan
# 0         4  0.010532       afghan
# 0         5  0.085954       afghan
# 1         1  0.001865  afghanistan
# 1         2  0.330732  afghanistan
# 1         3  0.000339  afghanistan
# 1         4  0.639427  afghanistan
# 1         5  0.027632  afghanistan
# 2         1  0.151820     american
# 2         2  0.783657     american
# 2         3  0.016745     american
# 2         4  0.001954     american
# 2         5  0.046048     american
# 3         5  0.999727   government
# 4         1  0.999680         iraq
# 5         1  0.783594     military
# 5         2  0.214228     military
# 5         3  0.001073     military
# 5         4  0.001073     military
# 5         5  0.000358     military
# 6         1  0.000243          new
# 6         3  0.997205          new
# 6         5  0.002430          new
# 7         1  0.000333    officials
# 7         2  0.041294    officials
# 7         5  0.958094    officials
# 8         1  0.996614    president
# 8         2  0.000272    president
# 8         3  0.002988    president
# 8         5  0.000272    president
# 9         3  0.999477       states
# 10        2  0.999489      taliban
# 11        3  0.999800       united
# 12        1  0.007836          war
# 12        3  0.000261          war
# 12        4  0.991728          war
# 13        1  0.855074   washington
# 13        2  0.001356   washington
# 13        3  0.096264   washington
# 13        5  0.047454   washington, R=14, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 1, 4, 3, 2])

# %%
pyLDAvis.save_html(model_viz, 'Visualizations/lda.html')

# %% [markdown]
# ## Adding LDA Topic clusters to DataFrame
# ___

# %%
articles['topic_cluster'] = pd.Series(model.columns())
articles.head()
# Out:
#                                             abstract  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                              snippet  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                       lead_paragraph  \
# 0   The United States, supported by Britain, toda...
# 1  IT will be, Americans have already been warned...
# 2  THE photographer Edward Grazda first visited A...
# 3  In the late 1980's, an American-based agent fo...
# 4   TOPDARA, Afghanistan, Oct. 7 — Sending bright...
#
#                                             headline  \
# 0  "U.S. and Britain Clearing Way for "Relentless...
# 1                                         "The World
# 2  "Art/Architecture; Images of Afghanistan, Befo...
# 3        "In 80"s, Afghan Militias Used U.S. Rifles"
# 4                 "Thunderous Attack Heard in Kabul"
#
#                                             keywords  \
# 0  The United States Taliban Rhode Television  Te...
# 1  World Trade Center (NYC) Airlines and Airplane...
# 2        Afghanistan Grazda Woodward   Photography
# 3  New York City Russia Washington (DC) Afghanist...
# 4  Afghanistan Taliban Dostum United States Polit...
#
#                     pub_date              news_desk    section_name  \
# 0  2001-10-07 05:00:00+00:00          International           World
# 1  2001-10-07 05:00:00+00:00    Week in Review Desk  Week in Review
# 2  2001-10-07 05:00:00+00:00  Arts and Leisure Desk            Arts
# 3  2001-10-07 05:00:00+00:00          National Desk            U.S.
# 4  2001-10-07 05:00:00+00:00          International           World
#
#   type_of_material  word_count  \
# 0             News        1333
# 1             News        1322
# 2        Interview        1638
# 3             News         603
# 4             News         611
#
#                                                  uri  \
# 0  nyt://article/02612e18-76c0-5447-bace-71473568...
# 1  nyt://article/0abd157f-d390-5787-bf89-4e87dad4...
# 2  nyt://article/15581e37-54ea-5aa4-bc80-34588ab1...
# 3  nyt://article/17f9cbdb-ff36-5df1-8a37-5c02edbb...
# 4  nyt://article/1a2a8209-9dd4-501b-a988-0c2adfc9...
#
#                                             all_text  overall_sentiment  \
# 0  The United States, supported by Britain, today...            -0.9648
# 1  Government can be expected to try to control, ...            -0.9761
# 2  Richard B Woodward interviews photographer Edw...            -0.6815
# 3  Violence Policy Center, Washington-based group...            -0.9661
# 4  Sending bright flashes of light and loud concu...             0.9022
#
#    topic_cluster
# 0              3
# 1              2
# 2              2
# 3              0
# 4              0

# %%
articles.shape
# Out:
# (37398, 14)

# %%
articles.isna().sum()
# Out:
# abstract               866
# snippet               4534
# lead_paragraph         957
# headline                 0
# keywords             10348
# pub_date                 0
# news_desk             2456
# section_name            11
# type_of_material      1494
# word_count               0
# uri                      0
# all_text                 0
# overall_sentiment        0
# topic_cluster            0
# dtype: int64

# %%
articles_to_viz = articles
articles_to_viz['topic_cluster'] = articles_to_viz['topic_cluster'].map(lambda x: x+1)

# %%
articles_to_viz.head()
# Out:
#                                             abstract  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                              snippet  \
# 0  The United States, supported by Britain, today...
# 1  Government can be expected to try to control, ...
# 2  Richard B Woodward interviews photographer Edw...
# 3  Violence Policy Center, Washington-based group...
# 4  Sending bright flashes of light and loud concu...
#
#                                       lead_paragraph  \
# 0   The United States, supported by Britain, toda...
# 1  IT will be, Americans have already been warned...
# 2  THE photographer Edward Grazda first visited A...
# 3  In the late 1980's, an American-based agent fo...
# 4   TOPDARA, Afghanistan, Oct. 7 — Sending bright...
#
#                                             headline  \
# 0  "U.S. and Britain Clearing Way for "Relentless...
# 1                                         "The World
# 2  "Art/Architecture; Images of Afghanistan, Befo...
# 3        "In 80"s, Afghan Militias Used U.S. Rifles"
# 4                 "Thunderous Attack Heard in Kabul"
#
#                                             keywords  \
# 0  The United States Taliban Rhode Television  Te...
# 1  World Trade Center (NYC) Airlines and Airplane...
# 2        Afghanistan Grazda Woodward   Photography
# 3  New York City Russia Washington (DC) Afghanist...
# 4  Afghanistan Taliban Dostum United States Polit...
#
#                     pub_date              news_desk    section_name  \
# 0  2001-10-07 05:00:00+00:00          International           World
# 1  2001-10-07 05:00:00+00:00    Week in Review Desk  Week in Review
# 2  2001-10-07 05:00:00+00:00  Arts and Leisure Desk            Arts
# 3  2001-10-07 05:00:00+00:00          National Desk            U.S.
# 4  2001-10-07 05:00:00+00:00          International           World
#
#   type_of_material  word_count  \
# 0             News        1333
# 1             News        1322
# 2        Interview        1638
# 3             News         603
# 4             News         611
#
#                                                  uri  \
# 0  nyt://article/02612e18-76c0-5447-bace-71473568...
# 1  nyt://article/0abd157f-d390-5787-bf89-4e87dad4...
# 2  nyt://article/15581e37-54ea-5aa4-bc80-34588ab1...
# 3  nyt://article/17f9cbdb-ff36-5df1-8a37-5c02edbb...
# 4  nyt://article/1a2a8209-9dd4-501b-a988-0c2adfc9...
#
#                                             all_text  overall_sentiment  \
# 0  The United States, supported by Britain, today...            -0.9648
# 1  Government can be expected to try to control, ...            -0.9761
# 2  Richard B Woodward interviews photographer Edw...            -0.6815
# 3  Violence Policy Center, Washington-based group...            -0.9661
# 4  Sending bright flashes of light and loud concu...             0.9022
#
#    topic_cluster
# 0              4
# 1              3
# 2              3
# 3              1
# 4              1

# %%
articles_to_viz.to_csv('datasets/articles_to_viz.csv')
